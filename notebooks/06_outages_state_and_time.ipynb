# %% [markdown]
# # Power outages with state & time info
# > Author: [Dawn Graham](https://dawngraham.github.io/)
#
# The first part of this notebook assigns location of power outages (as state abbreviations) to power outages. It then transforms event and restoration info to datetime values.
#
# The last adds a column to tweets data indicating if the tweet was at the same time as a verified outage.
#
# Versions used:
# - Python 3.6.6
# - pandas 0.23.4
# - numpy 1.15.4

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %% [markdown]
# ### Get data

# %%
df = pd.read_csv('../data/Grid_Disruption_00_14_standardized_cleaned.csv')
df.head()
# Out:
#                 Event Description  Year Date Event Began Time Event Began  \
# 0  Severe Weather - Thunderstorms  2014        6/30/2014          8:00 PM
# 1  Severe Weather - Thunderstorms  2014        6/30/2014         11:20 PM
# 2  Severe Weather - Thunderstorms  2014        6/30/2014          5:55 PM
# 3    Fuel Supply Emergency - Coal  2014        6/27/2014          1:21 PM
# 4     Physical Attack - Vandalism  2014        6/24/2014          2:54 PM
#
#   Date of Restoration Time of Restoration  \
# 0            7/2/2014             6:30 PM
# 1            7/1/2014             5:00 PM
# 2            7/1/2014             2:53 AM
# 3             Unknown             Unknown
# 4           6/24/2014             2:55 PM
#
#                                 Respondent       Geographic Areas NERC Region  \
# 0                 Exelon Corporation/ComEd               Illinois         RFC
# 1  Northern Indiana Public Service Company  North Central Indiana         RFC
# 2                              We Energies   Southeast  Wisconsin         MRO
# 3                              We Energies              Wisconsin         MRO
# 4               Tennessee Valley Authority   Nashville, Tennessee        SERC
#
#   Demand Loss (MW)  Number of Customers Affected                          Tags
# 0          Unknown                      420000.0  severe weather, thunderstorm
# 1          Unknown                      127000.0  severe weather, thunderstorm
# 2              424                      120000.0  severe weather, thunderstorm
# 3          Unknown                           NaN   fuel supply emergency, coal
# 4          Unknown                           NaN           vandalism, physical

# %%
df.shape
# Out:
# (1639, 12)

# %% [markdown]
# ### Drop rows
# Drop rows with missing geographic data.

# %%
# # Look at unique Geographic Areas
# sorted(df['Geographic Areas'].astype(str).unique())

# %%
df = df[df['Geographic Areas'] != '-']
df = df[df['Geographic Areas'].notnull()]

# %% [markdown]
# ### State abbreviations dictionary
# Bring in dictionary of state names and abbreviations. From [mGalarnyk/us_state_abbrev.py](https://gist.github.com/mGalarnyk/27c99c5f55133a2ceb42b8c9a450d794).

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'Puerto Rico': 'PR',
}

# %% [markdown]
# ### Create `State` column

# %%
# Set up empty column
df['State'] = ''

# %% [markdown]
# If `Geographic Areas` contains state name or abbreviation, include abbreviation in `State` column.

# %%
for state in us_state_abbrev:
    df.loc[df['Geographic Areas'].str.contains(state), 'State'] += f'{us_state_abbrev[state]} '
    df.loc[((df['Geographic Areas'].str.contains(us_state_abbrev[state])) & (us_state_abbrev[state] not in df['State'])), 'State'] += f'{us_state_abbrev[state]} '

# %% [markdown]
# Fill in missing values in `State` column.

# %%
df.loc[(df['Geographic Areas'].str.contains('Bakersfield') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Geographic Areas'].str.contains('Los Angeles') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Geographic Areas'].str.contains('Sacramento') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Geographic Areas'].str.contains('San Diego') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Geographic Areas'].str.contains('San Francisco') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Geographic Areas'].str.contains('Connecicut') & ('CT ' not in df['State'])), 'State'] += f'CT '
df.loc[(df['Geographic Areas'].str.contains('Maui') & ('HI ' not in df['State'])), 'State'] += f'HI '
df.loc[(df['Geographic Areas'].str.contains('Oahu') & ('HI ' not in df['State'])), 'State'] += f'HI '
df.loc[(df['Geographic Areas'].str.contains('Akron') & ('OH ' not in df['State'])), 'State'] += f'OH '
df.loc[(df['Geographic Areas'].str.contains('Cleveland') & ('OH ' not in df['State'])), 'State'] += f'OH '
df.loc[(df['Geographic Areas'].str.contains('Long Island') & ('NY ' not in df['State'])), 'State'] += f'NY '
df.loc[(df['Geographic Areas'].str.contains('Houston') & ('TX ' not in df['State'])), 'State'] += f'TX '

df.loc[(df['Respondent'].str.contains('California') & ('CA ' not in df['State'])), 'State'] += f'CA '
df.loc[(df['Respondent'].str.contains('Florida') & ('FL ' not in df['State'])), 'State'] += f'FL '
df.loc[(df['Respondent'].str.contains('Detroit') & ('MI ' not in df['State'])), 'State'] += f'MI '
df.loc[(df['Respondent'].str.contains('Texas') & ('TX ' not in df['State'])), 'State'] += f'TX '
df.loc[(df['Respondent'].str.contains('Puget Sound') & ('WA ' not in df['State'])), 'State'] += f'WA '
df.loc[(df['Respondent'].str.contains('Puerto Rico') & ('PR ' not in df['State'])), 'State'] += f'PR '

# %% [markdown]
# Correct incorrect or missing `State` values.

# %%
df.loc[df['Geographic Areas'].str.contains('VA')]
df.loc[1009, 'State'] = 'TN '

# %%
df.loc[876, 'State'] = 'CO '
df.loc[1006, 'State'] = 'KY '
df.loc[1073, 'State'] = 'WA '
df.loc[1107, 'State'] = 'CT ME MA NH RI VT '
df.loc[1139, 'State'] = 'FL '
df.loc[1210, 'State'] = 'AZ '

# %% [markdown]
# Update rows that included were flagged as `VA` because of West Virginia.

# %%
df.loc[12, 'State'] = 'WV '
df.loc[76, 'State'] = 'MD WV '
df.loc[317, 'State'] = 'WV '
df.loc[328, 'State'] = 'MD WV '
df.loc[402, 'State'] = 'MD WV '
df.loc[405, 'State'] = 'IN MI OH WV '
df.loc[410, 'State'] = 'WV '
df.loc[693, 'State'] = 'KY WV '
df.loc[733, 'State'] = 'KY WV '
df.loc[836, 'State'] = 'OH WV KY '
df.loc[836, 'State'] = 'PA WV '
df.loc[918, 'State'] = 'WV KY OH '
df.loc[991, 'State'] = 'KY WV OH '
df.loc[1340, 'State'] = 'MD WV PA '

# %% [markdown]
# ## Check remaining rows with no `State` value.

# %%
df[df['State'] == ''].shape
# Out:
# (44, 13)

# %%
df[df['State'] == '']
# Out:
#                                       Event Description  Year  \
# 82                          Physical Attack - Vandalism  2014
# 99                          Electrical System Islanding  2014
# 106      Voltage Reduction due to Severe Weather - Cold  2014
# 112          Public Appeal due to Severe Weather - Cold  2014
# 117          Public Appeal due to Severe Weather - Cold  2014
# 120      Voltage Reduction due to Severe Weather - Cold  2014
# 121      Voltage Reduction due to Severe Weather - Cold  2014
# 121                                             Unknown         RFC
# 161                                    Location Unknown        WECC
# 185                         Vancouver, British Columbia        WECC
# 187                            Western British Columbia        WECC
# 224                          Southern Company Territory        SERC
# 247                                             Unknown        WECC
# 367                                 CFE (Mexico & U.S.)        WECC
# 654                                          AEP Region         RFC
# 737                                             Unknown        SERC
# 796                                            Carolina        SERC
# 903                                  Delmarva Peninsula         RFC
# 946   Metro Denver (Jefferson, Adams, and Arapahoe C...        WECC
# 959                  The Entire ComEd Service Territory        SERC
# 983             Duke Energy Carolinas Balance Authority        SERC
# 985                             Southern Balancing Area        SERC
# 1002                                      CSWS-AEP West         RFC
# 1026                                        New England        NPCC
# 1071                                    City of Lubbock         TRE
# 1076                                The ComEd Territory         RFC
# 1104                         The Entire ComEd Territory         RFC
# 1108                                     Entergy System        SERC
# 1113                                     Entergy System        SERC
# 1114                         The Entire ComEd Territory         RFC
# 1118                       Entire BGE Service Territory         RFC
# 1142                         Restricted Coal Capability         RFC
# 1150                         Dominion Service Territory        SERC
# 1164                 The Entire ComEd Service Territory         RFC
# 1201                         Mid-Altantic Region of PJM         RFC
# 1273                        Southern Delmarva Peninsula         RFC
# 1281                                        New England        NPCC
# 1282                                        New England        NPCC
# 1324            Entire Delmarva Power service territory         RFC
# 1348  Nacogdoches, Lufkin, Tyler, Jacksonville, Rusk...       ERCOT
# 1419                                  Columbus District        ECAR
# 1424                                        Nova Scotia        NPCC
# 1432                                        Nova Scotia        NPCC
# 1501               Lake Colby, Lake Placid, Tupper Lake        NPCC
# 1530  All PPL including: Williamsport, Harrisburg, L...        MAAC
#
#      Demand Loss (MW)  Number of Customers Affected  \
# 82            Unknown                           NaN
# 99            Unknown                           NaN
# 106               576                           NaN
# 112           Unknown                           NaN
# 117           Unknown                           NaN
# 120           Unknown                           NaN
# 121           Unknown                           NaN
# 161               115                         433.0
# 185           Unknown                           NaN
# 187               420                           NaN
# 224               550                      165798.0
# 247           Unknown                           NaN
# 367               655                           NaN
# 654               UNK                       56000.0
# 737                 0                           0.0
# 796               NaN                       42000.0
# 903               NaN                       58491.0
# 946               150                       86058.0
# 959               NaN                      245000.0
# 983             1,000                      180000.0
# 985                75                       60000.0
# 1002              NaN                       59402.0
# 1026              NaN                      970000.0
# 1071              153                       71823.0
# 1076              NaN                      653000.0
# 1104              NaN                      165000.0
# 1108              300                          19.0
# 1113              300                          19.0
# 1114              NaN                      125000.0
# 1118              NaN                      108000.0
# 1142              NaN                           0.0
# 1150              170                      114618.0
# 1164              NaN                      237000.0
# 1201              NaN                           NaN
# 1273              380                      105000.0
# 1281              NaN                           NaN
# 1282          100-140                       77000.0
# 1324               50                       58000.0
# 1348              260                      200000.0
# 1419              800                      359171.0
# 1424              165                      165000.0
# 1432                -                           NaN
# 1501       Approx. 30                       18600.0
# 1530            1,300                      425000.0
#
#                                                  Tags State
# 82                                vandalism, physical
# 99                                          islanding
# 106                              severe weather, cold
# 112                              severe weather, cold
# 117                              severe weather, cold
# 120                              severe weather, cold
# 121                              severe weather, cold
# 161                                         islanding
# 185                         islanding, severe weather
# 187                                         islanding
# 224                      severe weather, thunderstorm
# 247                                         islanding
# 367               severe weather, dust, load shedding
# 654                                    severe weather
# 737                                  vandalism, cyber
# 796                                    severe weather
# 903                      severe weather, winter storm
# 946                      severe weather, thunderstorm
# 959                             severe weather, storm
# 983                      severe weather, winter storm
# 985                                    severe weather
# 1002                     severe weather, winter storm
# 1026                     severe weather, winter storm
# 1071  severe weather, thunderstorm, equipment failure
# 1076                                   severe weather
# 1104                                   severe weather
# 1108                                    load shedding
# 1113                                    load shedding
# 1114                                   severe weather
# 1118                            severe weather, storm
# 1142                            fuel supply emergency
# 1150                             severe weather, wind
# 1164                            severe weather, storm
# 1201                 voltage reduction, public appeal
# 1273         severe weather, hurricane/tropical storm
# 1281                                voltage reduction
# 1282                     severe weather, thunderstorm
# 1324                     severe weather, winter storm
# 1348         severe weather, hurricane/tropical storm
# 1419                     severe weather, winter storm
# 1424                     severe weather, winter storm
# 1432                                equipment failure
# 1501                                    public appeal
# 1530         severe weather, hurricane/tropical storm

# %% [markdown]
# ## Get begin / end times

# %%
df['Year'].value_counts()
# Out:
# 2011    307
# 2012    193
# 2013    170
# 2008    148
# 2014    125
# 2010    123
# 2009     97
# 2004     93
# 2006     91
# 2005     85
# 2007     78
# 2003     60
# 2000     29
# 2002     23
# 2001     15
# Name: Year, dtype: int64

# %%
# Quick filter to only use data from 2009 - 2012
df = df[(df['Year'] >= 2009) & (df['Year'] <= 2012)]

# %%
# Check to see if any begin/end times are missing
df.isnull().sum()
# Out:
# Event Description                 0
# Year                              0
# Date Event Began                  0
# Time Event Began                  0
# Date of Restoration               0
# Time of Restoration               0
# Respondent                        0
# Geographic Areas                  0
# NERC Region                       2
# Demand Loss (MW)                232
# Number of Customers Affected    168
# Tags                              0
# State                             0
# dtype: int64

# %% [markdown]
# ### Get datetime values

# %%
# Combine Began date & time into 'Outage Start' as datetime
df.loc[:,'Outage Start'] = pd.to_datetime(df['Date Event Began'].astype(str)+' '+df['Time Event Began'].astype(str))

# %%
# Drop the two rows where 'Date of Restoration' == 'Ongoing'
df = df[df['Date of Restoration'] != 'Ongoing']

# %%
# Combine Restoration date & time into 'Outage End' as datetime
df.loc[:,'Outage End'] = pd.to_datetime(df['Date of Restoration'].astype(str)+' '+df['Time of Restoration'].astype(str))

# %%
# Save only desired columns to outages.csv
df = df[['Respondent', 'Geographic Areas', 'State', 'Number of Customers Affected', 'Outage Start', 'Outage End']]
df.to_csv('./data/outages.csv')
df.head(3)
# Out:
#                       Respondent              Geographic Areas   State  \
# 295    City of Washington - (NC)                North Carolina     NC
# 296  Town of Stantonsburg - (NC)  Stantonsburg, North Carolina     NC
# 297           CenterPoint Energy                Houston, Texas  TX TX
#
#      Number of Customers Affected        Outage Start          Outage End
# 295                       12000.0 2012-12-31 14:21:00 2012-12-31 16:30:00
# 296                        1200.0 2012-12-26 14:50:00 2012-12-26 19:40:00
# 297                      262000.0 2012-12-25 09:28:00 2012-12-26 16:28:00

# %% [markdown]
# ---
# ## Check if tweets coincide with power outages

# %%
tweets = pd.read_csv('../data/combined_monthlytweets.csv')

# Set `timestamp` to datetime and set it to index
tweets['timestamp'] = pd.to_datetime(tweets['timestamp'])
tweets.set_index('timestamp', inplace=True)
tweets.head(3)
# Out:
#                                      id  likes  \
# timestamp
# 2012-11-01 23:50:22  264152432282578945      1
# 2012-11-01 23:45:13  264151136792109056      0
# 2012-11-01 23:34:44  264148498352590849      1
#
#                                                                  query  \
# timestamp
# 2012-11-01 23:50:22  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:45:13  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:34:44  EversourceMA OR EversourceNH OR VelcoVT OR nat...
#
#                      replies  retweets  \
# timestamp
# 2012-11-01 23:50:22      1.0         3
# 2012-11-01 23:45:13      0.0         0
# 2012-11-01 23:34:44      0.0         1
#
#                                                                   text  \
# timestamp
# 2012-11-01 23:50:22  Tom May, CEO of Northeast Utilities, the paren...
# 2012-11-01 23:45:13  @NYGovCuomo @lipanews @nationalgridus @nyseand...
# 2012-11-01 23:34:44  Some amazing video from the Wareham microburst...
#
#                                user
# timestamp
# 2012-11-01 23:50:22    EversourceMA
# 2012-11-01 23:45:13  readyforthenet
# 2012-11-01 23:34:44    EversourceMA

# %%
# Dataframe contains sponsored tweets outside of our time of interest (September 2009 to end of December 2012).
# Filtering to dates of interest.
tweets = tweets[:'2012']

# %%
# Set up 'outage' column with all values set to 0 and empty 'outage_state' column
tweets['outage'] = 0
tweets['outage_state'] = ''

# %%
tweets.shape
# Out:
# (38069, 9)

# %%
count = 0
for i in range(len(tweets)):
    count += 1
    for row in range(len(df)):
        if ((df.iloc[row]['Outage Start'] <= tweets.index[i]) & (tweets.index[i] <= df.iloc[row]['Outage End'])):
#             ## Print to confirm tweet times are during an outage
#             print('Outage start:', df.iloc[row]['Outage Start'])
#             print('Tweet time:  ', tweets.index[i])
#             print('Outage end:  ', df.iloc[row]['Outage End'])
#             print('Outage state: ', df.iloc[row]['State'])
#             print('')
            tweets.loc[tweets.index[i], 'outage'] = 1
            tweets.loc[tweets.index[i], 'outage_state'] = tweets['outage_state'][i] + ' ' + f"{df.iloc[row]['State']}"
#             break
    if (count) % 100 == 0:
         print(count, end=' ')
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800 9900 10000 10100 10200 10300 10400 10500 10600 10700 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000 13100 13200 13300 13400 13500 13600 13700 13800 13900 14000 14100 14200 14300 14400 14500 14600 14700 14800 14900 15000 15100 15200 15300 15400 15500 15600 15700 15800 15900 16000 16100 16200 16300 16400 16500 16600 16700 16800 16900 17000 17100 17200 17300 17400 17500 17600 17700 17800 17900 18000 18100 18200 18300 18400 18500 18600 18700 18800 18900 19000 19100 19200 19300 19400 19500 19600 19700 19800 19900 20000 20100 20200 20300 20400 20500 20600 20700 20800 20900 21000 21100 21200 21300 21400 21500 21600 21700 21800 21900 22000 22100 22200 22300 22400 22500 22600 22700 22800 22900 23000 23100 23200 23300 23400 23500 23600 23700 23800 23900 24000 24100 24200 24300 24400 24500 24600 24700 24800 24900 25000 25100 25200 25300 25400 25500 25600 25700 25800 25900 26000 26100 26200 26300 26400 26500 26600 26700 26800 26900 27000 27100 27200 27300 27400 27500 27600 27700 27800 27900 28000 28100 28200 28300 28400 28500 28600 28700 28800 28900 29000 29100 29200 29300 29400 29500 29600 29700 29800 29900 30000 30100 30200 30300 30400 30500 30600 30700 30800 30900 31000 31100 31200 31300 31400 31500 31600 31700 31800 31900 32000 32100 32200 32300 32400 32500 32600 32700 32800 32900 33000 33100 33200 33300 33400 33500 33600 33700 33800 33900 34000 34100 34200 34300 34400 34500 34600 34700 34800 34900 35000 35100 35200 35300 35400 35500 35600 35700 35800 35900 36000 36100 36200 36300 36400 36500 36600 36700 36800 36900 37000 37100 37200 37300 37400 37500 37600 37700 37800 37900 38000

# %%
# Remove duplicates in `outage state` column
tweets['outage_state'] = tweets['outage_state'].str.split()\
         .apply(lambda x: OrderedDict.fromkeys(x).keys()).str.join(' ')

# %%
tweets.head()
# Out:
#                                      id  likes  \
# timestamp
# 2012-11-01 23:50:22  264152432282578945      1
# 2012-11-01 23:45:13  264151136792109056      0
# 2012-11-01 23:34:44  264148498352590849      1
# 2012-11-01 23:34:20  264148399190851584      0
# 2012-11-01 23:31:56  264147793147490304      0
#
#                                                                  query  \
# timestamp
# 2012-11-01 23:50:22  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:45:13  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:34:44  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:34:20  EversourceMA OR EversourceNH OR VelcoVT OR nat...
# 2012-11-01 23:31:56  EversourceMA OR EversourceNH OR VelcoVT OR nat...
#
#                      replies  retweets  \
# timestamp
# 2012-11-01 23:50:22      1.0         3
# 2012-11-01 23:45:13      0.0         0
# 2012-11-01 23:34:44      0.0         1
# 2012-11-01 23:34:20      0.0         0
# 2012-11-01 23:31:56      1.0         8
#
#                                                                   text  \
# timestamp
# 2012-11-01 23:50:22  Tom May, CEO of Northeast Utilities, the paren...
# 2012-11-01 23:45:13  @NYGovCuomo @lipanews @nationalgridus @nyseand...
# 2012-11-01 23:34:44  Some amazing video from the Wareham microburst...
# 2012-11-01 23:34:20  @nationalgridus Call me if you need some help ...
# 2012-11-01 23:31:56  Current PSNH statewide w/o power: 885. We're d...
#
#                                user  outage  \
# timestamp
# 2012-11-01 23:50:22    EversourceMA       1
# 2012-11-01 23:45:13  readyforthenet       1
# 2012-11-01 23:34:44    EversourceMA       1
# 2012-11-01 23:34:20      sparky1000       1
# 2012-11-01 23:31:56    EversourceNH       1
#
#                                             outage_state
# timestamp
# 2012-11-01 23:50:22  WV OH PA NJ CT MA NY DE MD IN KY MI
# 2012-11-01 23:45:13  WV OH PA NJ CT MA NY DE MD IN KY MI
# 2012-11-01 23:34:44  WV OH PA NJ CT MA NY DE MD IN KY MI
# 2012-11-01 23:34:20  WV OH PA NJ CT MA NY DE MD IN KY MI
# 2012-11-01 23:31:56  WV OH PA NJ CT MA NY DE MD IN KY MI

# %%
tweets['outage'].value_counts()
# Out:
# 1    20431
# 0    17638
# Name: outage, dtype: int64

# %%
tweets.to_csv('../data/combined_tweets_outages.csv')
